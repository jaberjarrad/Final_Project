# %%
import pandas as pd
import numpy as np

# %%
heartDisease = pd.read_csv("tubes2_HeartDisease_train.csv")

# %%
heartDisease = heartDisease[heartDisease.Column4 != '?']
heartDisease = heartDisease[heartDisease.Column5 != '?']
heartDisease = heartDisease[heartDisease.Column6 != '?']
heartDisease = heartDisease[heartDisease.Column7 != '?']
heartDisease = heartDisease[heartDisease.Column8 != '?']
heartDisease = heartDisease[heartDisease.Column9 != '?']
heartDisease = heartDisease[heartDisease.Column10 != '?']
heartDisease = heartDisease[heartDisease.Column11 != '?']
heartDisease = heartDisease[heartDisease.Column12 != '?']
heartDisease = heartDisease[heartDisease.Column13 != '?']

# %%
heartDisease = heartDisease.rename(columns={"Column1": "Age",
                                       "Column2": "Sex",
                                       "Column3": "Chest-Pain_Type",
                                       "Column4": "Resting_Blood_Pressure",
                                       "Column5": "Serum Cholestrol",
                                       "Column6": "Fasting_Blood_Sugar",
                                       "Column7": "RestingECG",
                                       "Column8": "Max_Heart_Rate",
                                       "Column9": "Exercise_Induced_Angina",
                                       "Column10": "ST_Depression_Induced_By_Exercise_Relative_To_Rest",
                                       "Column11": "Peak_Exercise_ST_Segment",
                                       "Column12": "#_Major_Vessels",
                                       "Column13": "Thal",
                                       "Column14": "Heart_Disease_Status",})

# %%
heartDisease['Index'] = np.arange(len(heartDisease))
heartDisease.set_index('Index')
# Out:
#        Age  Sex  Chest-Pain_Type Resting_Blood_Pressure Serum Cholestrol  \
# Index
# 0       54    0                3                    135              304
# 1       64    0                4                    130              303
# 2       54    1                3                    120              258
# 3       49    1                3                    118              149
# 4       55    0                2                    132              342
# 5       57    1                4                    150              276
# 6       67    1                4                    125              254
# 7       45    0                2                    112              160
# 8       51    0                3                    120              295
# 9       64    0                4                    180              325
# 10      52    1                4                    108              233
# 11      58    0                4                    100              248
# ...

# %%
heartDisease.to_csv("heartDisease")
