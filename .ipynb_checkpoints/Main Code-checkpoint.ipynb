# %%
#Dependancies

import pandas as pd
import numpy as np

# %%
#Reading csv files

demographicDf = pd.read_csv("resources/demographic.csv")
labsDf = pd.read_csv("resources/labs.csv")
medicationsDf = pd.read_csv("resources/medications.csv", encoding="ISO-8859-1")

# %%
#Drops conditions in medicationsDf that appear less than 100 times

medValues = medicationsDf["RXDRSD1"].value_counts(dropna=False)
medicationsDf = medicationsDf[medicationsDf['RXDRSD1'].isin(medValues[medValues >= 100].index)]

# %%
#Replaces null values with a "Healthy" string

medicationsDf["RXDRSD1"] = medicationsDf["RXDRSD1"].fillna("Healthy")

# %%
#Renames the columns in medicationsDf

medicationsDf = medicationsDf.rename(columns=\
                                    {"RXDUSE": "Medications_Teken_Last_30_Days",\
                                      "RXDDRUG": "Generic_Drug_Name",\
                                      "RXDDRGID": "Generic_Drug_Code", \
                                      "RXQSEEN": "Was_Prescription_Container_Seen_By_Interviewer",\
                                      "RXDDAYS": "Duration_Taken_Medications",\
                                      "RXDRSC1": "ICD_10_CM_Code_1",\
                                      "RXDRSC2": "ICD_10_CM_Code_2",\
                                      "RXDRSC3": "ICD_10_CM_Code_3",\
                                      "RXDRSD1": "ICD_10_CM_Code_1_Description",\
                                      "RXDRSD2": "ICD_10_CM_Code_2_Description",\
                                      "RXDRSD3": "ICD_10_CM_Code_3_Description",\
                                      "RXDCOUNT":"The_Number_Of_Prescription_Medicines_Reported"
                                    })

# %%
#Isolates the SEQN column into it's own dataframe
labSEQN = labsDf[["SEQN"]]

#Sets null values to 0 and non-null values to 1
newLab = labsDf.notnull().astype('int')

#Drops the current SEQN column which only has values of 1 currently
newLab = newLab.drop(columns=["SEQN"])

#Brings the isolated SEQN column back into the dataframe
newLab = newLab.join(labSEQN, how='outer')

#Moves the SEQN column to the far left of our dataframe
columnList = list(newLab.columns.values)
columnList.pop(columnList.index('SEQN'))
newLab = newLab[['SEQN']+columnList]

#Drops new null values
newLab = newLab.dropna()

#Changes 0 values to 2 values for future division
for col in columnList:
    newLab[col] = newLab[col].replace(0, 2, regex=True)
# Out:
# 1    8052
# 2    1761
# Name: URXUMA, dtype: int64
# 1    8052
# 2    1761
# Name: URXUMS, dtype: int64
# 1    8052
# 2    1761
# Name: URXUCR.x, dtype: int64
# 1    8052
# 2    1761
# Name: URXCRS, dtype: int64
# 1    8052
# 2    1761
# Name: URDACT, dtype: int64
# 2    6484
# 1    3329
# Name: WTSAF2YR.x, dtype: int64
# 2    6668
# 1    3145
# Name: LBXAPB, dtype: int64
# 2    6668
# 1    3145
# Name: LBDAPBSI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSAL, dtype: int64
# 1    6553
# 2    3260
# Name: LBDSALSI, dtype: int64
# 1    6552
# 2    3261
# Name: LBXSAPSI, dtype: int64
# 1    6551
# 2    3262
# Name: LBXSASSI, dtype: int64
# 1    6551
# 2    3262
# Name: LBXSATSI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSBU, dtype: int64
# 1    6553
# 2    3260
# Name: LBDSBUSI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSC3SI, dtype: int64
# 1    6511
# 2    3302
# Name: LBXSCA, dtype: int64
# 1    6511
# 2    3302
# Name: LBDSCASI, dtype: int64
# 1    6551
# 2    3262
# Name: LBXSCH, dtype: int64
# 1    6551
# 2    3262
# Name: LBDSCHSI, dtype: int64
# 1    6542
# 2    3271
# Name: LBXSCK, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSCLSI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSCR, dtype: int64
# 1    6553
# 2    3260
# Name: LBDSCRSI, dtype: int64
# 1    6544
# 2    3269
# Name: LBXSGB, dtype: int64
# 1    6544
# 2    3269
# Name: LBDSGBSI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSGL, dtype: int64
# 1    6553
# 2    3260
# Name: LBDSGLSI, dtype: int64
# 1    6552
# 2    3261
# Name: LBXSGTSI, dtype: int64
# 1    6527
# 2    3286
# Name: LBXSIR, dtype: int64
# 1    6527
# 2    3286
# Name: LBDSIRSI, dtype: int64
# 1    6552
# 2    3261
# Name: LBXSKSI, dtype: int64
# 1    6551
# 2    3262
# Name: LBXSLDSI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSNASI, dtype: int64
# 1    6553
# 2    3260
# Name: LBXSOSSI, dtype: int64
# 1    6552
# 2    3261
# Name: LBXSPH, dtype: int64
# 1    6552
# 2    3261
# Name: LBDSPHSI, dtype: int64
# 1    6549
# 2    3264
# Name: LBXSTB, dtype: int64
# 1    6549
# 2    3264
# Name: LBDSTBSI, dtype: int64
# 1    6544
# 2    3269
# Name: LBXSTP, dtype: int64
# 1    6544
# 2    3269
# Name: LBDSTPSI, dtype: int64
# 1    6549
# 2    3264
# Name: LBXSTR, dtype: int64
# 1    6549
# 2    3264
# Name: LBDSTRSI, dtype: int64
# 1    6551
# 2    3262
# Name: LBXSUA, dtype: int64
# 1    6551
# 2    3262
# Name: LBDSUASI, dtype: int64
# 1    8544
# 2    1269
# Name: LBXWBCSI, dtype: int64
# 1    8519
# 2    1294
# Name: LBXLYPCT, dtype: int64
# 1    8519
# 2    1294
# Name: LBXMOPCT, dtype: int64
# 1    8519
# 2    1294
# Name: LBXNEPCT, dtype: int64
# 1    8519
# 2    1294
# Name: LBXEOPCT, dtype: int64
# 1    8519
# 2    1294
# Name: LBXBAPCT, dtype: int64
# 1    8519
# 2    1294
# Name: LBDLYMNO, dtype: int64
# 1    8519
# 2    1294
# Name: LBDMONO, dtype: int64
# 1    8519
# 2    1294
# Name: LBDNENO, dtype: int64
# 1    8519
# 2    1294
# Name: LBDEONO, dtype: int64
# 1    8519
# 2    1294
# Name: LBDBANO, dtype: int64
# 1    8544
# 2    1269
# Name: LBXRBCSI, dtype: int64
# 1    8544
# 2    1269
# Name: LBXHGB, dtype: int64
# 1    8544
# 2    1269
# Name: LBXHCT, dtype: int64
# 1    8544
# 2    1269
# Name: LBXMCVSI, dtype: int64
# 1    8544
# 2    1269
# Name: LBXMCHSI, dtype: int64
# 1    8544
# 2    1269
# Name: LBXMC, dtype: int64
# 1    8544
# 2    1269
# Name: LBXRDW, dtype: int64
# 1    8544
# 2    1269
# Name: LBXPLTSI, dtype: int64
# 1    8544
# 2    1269
# Name: LBXMPSI, dtype: int64
# 2    7639
# 1    2174
# Name: URXUCL, dtype: int64
# 2    7058
# 1    2755
# Name: WTSA2YR.x, dtype: int64
# 2    7293
# 1    2520
# Name: LBXSCU, dtype: int64
# 2    7293
# 1    2520
# Name: LBDSCUSI, dtype: int64
# 2    7294
# 1    2519
# Name: LBXSSE, dtype: int64
# 2    7294
# 1    2519
# Name: LBDSSESI, dtype: int64
# 2    7294
# 1    2519
# Name: LBXSZN, dtype: int64
# 2    7294
# 1    2519
# Name: LBDSZNSI, dtype: int64
# 2    7132
# 1    2681
# Name: URXUCR.y, dtype: int64
# 2    7036
# 1    2777
# Name: WTSB2YR.x, dtype: int64
# 2    7127
# 1    2686
# Name: URXBP3, dtype: int64
# 2    7127
# 1    2686
# Name: URDBP3LC, dtype: int64
# 2    7127
# 1    2686
# Name: URXBPH, dtype: int64
# 2    7127
# 1    2686
# Name: URDBPHLC, dtype: int64
# 2    7131
# 1    2682
# Name: URXBPF, dtype: int64
# 2    7131
# 1    2682
# Name: URDBPFLC, dtype: int64
# 2    7131
# 1    2682
# Name: URXBPS, dtype: int64
# 2    7131
# 1    2682
# Name: URDBPSLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXTLC, dtype: int64
# 2    7127
# 1    2686
# Name: URDTLCLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXTRS, dtype: int64
# 2    7127
# 1    2686
# Name: URDTRSLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXBUP, dtype: int64
# 2    7127
# 1    2686
# Name: URDBUPLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXEPB, dtype: int64
# 2    7127
# 1    2686
# Name: URDEPBLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXMPB, dtype: int64
# 2    7127
# 1    2686
# Name: URDMPBLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXPPB, dtype: int64
# 2    7127
# 1    2686
# Name: URDPPBLC, dtype: int64
# 2    7127
# 1    2686
# Name: URX14D, dtype: int64
# 2    7127
# 1    2686
# Name: URD14DLC, dtype: int64
# 2    7127
# 1    2686
# Name: URXDCB, dtype: int64
# 2    7127
# 1    2686
# Name: URDDCBLC, dtype: int64
# 2    7123
# 1    2690
# Name: URXUCR, dtype: int64
# 1    9182
# 2     631
# Name: PHQ020, dtype: int64
# 2    9684
# 1     129
# Name: PHACOFHR, dtype: int64
# 2    9684
# 1     129
# Name: PHACOFMN, dtype: int64
# 1    9182
# 2     631
# Name: PHQ030, dtype: int64
# 2    9771
# 1      42
# Name: PHAALCHR, dtype: int64
# 2    9771
# 1      42
# Name: PHAALCMN, dtype: int64
# 1    9182
# 2     631
# Name: PHQ040, dtype: int64
# 2    9442
# 1     371
# Name: PHAGUMHR, dtype: int64
# 2    9442
# 1     371
# Name: PHAGUMMN, dtype: int64
# 1    9182
# 2     631
# Name: PHQ050, dtype: int64
# 2    9776
# 1      37
# Name: PHAANTHR, dtype: int64
# 2    9776
# 1      37
# Name: PHAANTMN, dtype: int64
# 1    9182
# 2     631
# Name: PHQ060, dtype: int64
# 2    9727
# 1      86
# Name: PHASUPHR, dtype: int64
# 2    9727
# 1      86
# Name: PHASUPMN, dtype: int64
# 1    9182
# 2     631
# Name: PHAFSTHR.x, dtype: int64
# 1    9182
# 2     631
# Name: PHAFSTMN.x, dtype: int64
# 1    9422
# 2     391
# Name: PHDSESN, dtype: int64
# 2    7488
# 1    2325
# Name: LBDPFL, dtype: int64
# 2    5713
# 1    4100
# Name: LBDWFL, dtype: int64
# 1    7624
# 2    2189
# Name: LBDHDD, dtype: int64
# 1    7624
# 2    2189
# Name: LBDHDDSI, dtype: int64
# 1    8264
# 2    1549
# Name: LBXHA, dtype: int64
# 1    8261
# 2    1552
# Name: LBXHBS, dtype: int64
# 1    7656
# 2    2157
# Name: LBXHBC, dtype: int64
# 1    7652
# 2    2161
# Name: LBDHBG, dtype: int64
# 1    7652
# 2    2161
# Name: LBDHD, dtype: int64
# 2    9676
# 1     137
# Name: LBXHCR, dtype: int64
# 2    9746
# 1      67
# Name: LBXHCG, dtype: int64
# 1    7656
# 2    2157
# Name: LBDHEG, dtype: int64
# 1    7656
# 2    2157
# Name: LBDHEM, dtype: int64
# 2    6144
# 1    3669
# Name: LBXHE1, dtype: int64
# 2    6768
# 1    3045
# Name: LBXHE2, dtype: int64
# 1    6643
# 2    3170
# Name: LBXGH, dtype: int64
# 2    5901
# 1    3912
# Name: LBDHI, dtype: int64
# 1    5057
# 2    4756
# Name: ORXGH, dtype: int64
# 1    5057
# 2    4756
# Name: ORXGL, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH06, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH11, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH16, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH18, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH26, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH31, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH33, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH35, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH39, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH40, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH42, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH45, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH51, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH52, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH53, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH54, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH55, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH56, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH58, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH59, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH61, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH62, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH64, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH66, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH67, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH68, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH69, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH70, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH71, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH72, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH73, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH81, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH82, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH83, dtype: int64
# 1    5057
# 2    4756
# Name: ORXH84, dtype: int64
# 1    5057
# 2    4756
# Name: ORXHPC, dtype: int64
# 1    5057
# 2    4756
# Name: ORXHPI, dtype: int64
# 1    5057
# 2    4756
# Name: ORXHPV, dtype: int64
# 2    7945
# 1    1868
# Name: LBDRPCR.x, dtype: int64
# 2    8056
# 1    1757
# Name: LBDRHP.x, dtype: int64
# 2    8056
# 1    1757
# Name: LBDRLP.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR06.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR11.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR16.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR18.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR26.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR31.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR33.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR35.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR39.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR40.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR42.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR45.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR51.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR52.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR53.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR54.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR55.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR56.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR58.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR59.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR61.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR62.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR64.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR66.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR67.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR68.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR69.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR70.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR71.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR72.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR73.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR81.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR82.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR83.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR84.x, dtype: int64
# 2    7945
# 1    1868
# Name: LBDR89.x, dtype: int64
# 2    8056
# 1    1757
# Name: LBDRPI.x, dtype: int64
# 2    7818
# 1    1995
# Name: LBXHP2C, dtype: int64
# 2    7818
# 1    1995
# Name: LBDRPCR.y, dtype: int64
# 2    7828
# 1    1985
# Name: LBDRHP.y, dtype: int64
# 2    7828
# 1    1985
# Name: LBDRLP.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR06.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR11.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR16.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR18.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR26.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR31.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR33.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR35.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR39.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR40.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR42.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR45.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR51.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR52.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR53.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR54.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR55.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR56.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR58.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR59.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR61.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR62.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR64.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR66.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR67.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR68.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR69.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR70.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR71.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR72.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR73.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR81.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR82.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR83.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR84.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDR89.y, dtype: int64
# 2    7818
# 1    1995
# Name: LBDRPI.y, dtype: int64
# 2    6484
# 1    3329
# Name: WTSAF2YR.y, dtype: int64
# 2    6720
# 1    3093
# Name: LBXIN, dtype: int64
# 2    6720
# 1    3093
# Name: LBDINSI, dtype: int64
# 2    6522
# 1    3291
# Name: PHAFSTHR.y, dtype: int64
# 2    6522
# 1    3291
# Name: PHAFSTMN.y, dtype: int64
# 2    7147
# 1    2666
# Name: URXUIO, dtype: int64
# 2    6484
# 1    3329
# Name: WTSAF2YR, dtype: int64
# 2    6667
# 1    3146
# Name: LBXTR, dtype: int64
# 2    6667
# 1    3146
# Name: LBDTRSI, dtype: int64
# 2    6708
# 1    3105
# Name: LBDLDL, dtype: int64
# 2    6708
# 1    3105
# Name: LBDLDLSI, dtype: int64
# 1    5932
# 2    3881
# Name: WTSH2YR.x, dtype: int64
# 1    5175
# 2    4638
# Name: LBXIHG, dtype: int64
# 1    5175
# 2    4638
# Name: LBDIHGSI, dtype: int64
# 1    5175
# 2    4638
# Name: LBDIHGLC, dtype: int64
# 1    5175
# 2    4638
# Name: LBXBGE, dtype: int64
# 1    5175
# 2    4638
# Name: LBDBGELC, dtype: int64
# 1    5175
# 2    4638
# Name: LBXBGM, dtype: int64
# 1    5175
# 2    4638
# Name: LBDBGMLC, dtype: int64
# 2    6904
# 1    2909
# Name: WTSOG2YR, dtype: int64
# 2    7468
# 1    2345
# Name: LBXGLT, dtype: int64
# 2    7468
# 1    2345
# Name: LBDGLTSI, dtype: int64
# 2    7404
# 1    2409
# Name: GTDSCMMN, dtype: int64
# 2    7404
# 1    2409
# Name: GTDDR1MN, dtype: int64
# 2    7467
# 1    2346
# Name: GTDBL2MN, dtype: int64
# 2    7467
# 1    2346
# Name: GTDDR2MN, dtype: int64
# 2    7299
# 1    2514
# Name: GTXDRANK, dtype: int64
# 2    6904
# 1    2909
# Name: PHAFSTHR, dtype: int64
# 2    6904
# 1    2909
# Name: PHAFSTMN, dtype: int64
# 2    6904
# 1    2909
# Name: GTDCODE, dtype: int64
# 2    7058
# 1    2755
# Name: WTSA2YR.y, dtype: int64
# 2    7173
# 1    2640
# Name: URXP01, dtype: int64
# 2    7173
# 1    2640
# Name: URDP01LC, dtype: int64
# 2    7172
# 1    2641
# Name: URXP02, dtype: int64
# 2    7172
# 1    2641
# Name: URDP02LC, dtype: int64
# 2    7163
# 1    2650
# Name: URXP03, dtype: int64
# 2    7163
# 1    2650
# Name: URDP03LC, dtype: int64
# 2    7163
# 1    2650
# Name: URXP04, dtype: int64
# 2    7163
# 1    2650
# Name: URDP04LC, dtype: int64
# 2    7163
# 1    2650
# Name: URXP06, dtype: int64
# 2    7163
# 1    2650
# Name: URDP06LC, dtype: int64
# 2    7163
# 1    2650
# Name: URXP10, dtype: int64
# 2    7163
# 1    2650
# Name: URDP10LC, dtype: int64
# 2    7163
# 1    2650
# Name: URXP25, dtype: int64
# 2    7163
# 1    2650
# Name: URDP25LC, dtype: int64
# 2    7058
# 1    2755
# Name: WTSA2YR, dtype: int64
# 2    7169
# 1    2644
# Name: URXUP8, dtype: int64
# 2    7169
# 1    2644
# Name: URDUP8LC, dtype: int64
# 2    7169
# 1    2644
# Name: URXNO3, dtype: int64
# 2    7169
# 1    2644
# Name: URDNO3LC, dtype: int64
# 2    7170
# 1    2643
# Name: URXSCN, dtype: int64
# 2    7170
# 1    2643
# Name: URDSCNLC, dtype: int64
# 2    7474
# 1    2339
# Name: WTSB2YR.y, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFDE, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFDEL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFHS, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFHSL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXMPAH, dtype: int64
# 2    7645
# 1    2168
# Name: LBDMPAHL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFBS, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFBSL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFHP, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFHPL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFNA, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFNAL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFUA, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFUAL, dtype: int64
# 2    7645
# 1    2168
# Name: LBXPFDO, dtype: int64
# 2    7645
# 1    2168
# Name: LBDPFDOL, dtype: int64
# 2    7036
# 1    2777
# Name: WTSB2YR, dtype: int64
# 2    7128
# 1    2685
# Name: URXCNP, dtype: int64
# 2    7128
# 1    2685
# Name: URDCNPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXCOP, dtype: int64
# 2    7128
# 1    2685
# Name: URDCOPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXECP, dtype: int64
# 2    7128
# 1    2685
# Name: URDECPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMBP, dtype: int64
# 2    7128
# 1    2685
# Name: URDMBPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMC1, dtype: int64
# 2    7128
# 1    2685
# Name: URDMC1LC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMEP, dtype: int64
# 2    7128
# 1    2685
# Name: URDMEPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMHH, dtype: int64
# 2    7128
# 1    2685
# Name: URDMHHLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMHNC, dtype: int64
# 2    7128
# 1    2685
# Name: URDMCHLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMHP, dtype: int64
# 2    7128
# 1    2685
# Name: URDMHPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMIB, dtype: int64
# 2    7128
# 1    2685
# Name: URDMIBLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMNP, dtype: int64
# 2    7128
# 1    2685
# Name: URDMNPLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMOH, dtype: int64
# 2    7128
# 1    2685
# Name: URDMOHLC, dtype: int64
# 2    7128
# 1    2685
# Name: URXMZP, dtype: int64
# 2    7128
# 1    2685
# Name: URDMZPLC, dtype: int64
# 1    7624
# 2    2189
# Name: LBXTC, dtype: int64
# 1    7624
# 2    2189
# Name: LBDTCSI, dtype: int64
# 1    7577
# 2    2236
# Name: LBXTTG, dtype: int64
# 2    9779
# 1      34
# Name: LBXEMA, dtype: int64
# 1    5932
# 2    3881
# Name: WTSH2YR.y, dtype: int64
# 1    5215
# 2    4598
# Name: LBXBPB, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBPBSI, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBPBLC, dtype: int64
# 1    5215
# 2    4598
# Name: LBXBCD, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBCDSI, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBCDLC, dtype: int64
# 1    5215
# 2    4598
# Name: LBXTHG, dtype: int64
# 1    5215
# 2    4598
# Name: LBDTHGSI, dtype: int64
# 1    5215
# 2    4598
# Name: LBDTHGLC, dtype: int64
# 1    5215
# 2    4598
# Name: LBXBSE, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBSESI, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBSELC, dtype: int64
# 1    5215
# 2    4598
# Name: LBXBMN, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBMNSI, dtype: int64
# 1    5215
# 2    4598
# Name: LBDBMNLC, dtype: int64
# 2    5756
# 1    4057
# Name: URXUTRI, dtype: int64
# 2    7159
# 1    2654
# Name: URXUAS3, dtype: int64
# 2    7159
# 1    2654
# Name: URDUA3LC, dtype: int64
# 2    7159
# 1    2654
# Name: URXUAS5, dtype: int64
# 2    7159
# 1    2654
# Name: URDUA5LC, dtype: int64
# 2    7159
# 1    2654
# Name: URXUAB, dtype: int64
# 2    7159
# 1    2654
# Name: URDUABLC, dtype: int64
# 2    7159
# 1    2654
# Name: URXUAC, dtype: int64
# 2    7159
# 1    2654
# Name: URDUACLC, dtype: int64
# 2    7159
# 1    2654
# Name: URXUDMA, dtype: int64
# 2    7159
# 1    2654
# Name: URDUDALC, dtype: int64
# 2    7159
# 1    2654
# Name: URXUMMA, dtype: int64
# 2    7159
# 1    2654
# Name: URDUMMAL, dtype: int64
# 1    8057
# 2    1756
# Name: URXVOL1, dtype: int64
# 1    7150
# 2    2663
# Name: URDFLOW1, dtype: int64
# 2    7957
# 1    1856
# Name: URXVOL2, dtype: int64
# 2    7958
# 1    1855
# Name: URDFLOW2, dtype: int64
# 2    9714
# 1      99
# Name: URXVOL3, dtype: int64
# 2    9714
# 1      99
# Name: URDFLOW3, dtype: int64
# 2    7147
# 1    2666
# Name: URXUHG, dtype: int64
# 2    7147
# 1    2666
# Name: URDUHGLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUBA, dtype: int64
# 2    7149
# 1    2664
# Name: URDUBALC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUCD, dtype: int64
# 2    7149
# 1    2664
# Name: URDUCDLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUCO, dtype: int64
# 2    7149
# 1    2664
# Name: URDUCOLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUCS, dtype: int64
# 2    7149
# 1    2664
# Name: URDUCSLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUMO, dtype: int64
# 2    7149
# 1    2664
# Name: URDUMOLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUMN, dtype: int64
# 2    7149
# 1    2664
# Name: URDUMNLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUPB, dtype: int64
# 2    7149
# 1    2664
# Name: URDUPBLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUSB, dtype: int64
# 2    7149
# 1    2664
# Name: URDUSBLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUSN, dtype: int64
# 2    7149
# 1    2664
# Name: URDUSNLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUSR, dtype: int64
# 2    7149
# 1    2664
# Name: URDUSRLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUTL, dtype: int64
# 2    7149
# 1    2664
# Name: URDUTLLC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUTU, dtype: int64
# 2    7149
# 1    2664
# Name: URDUTULC, dtype: int64
# 2    7149
# 1    2664
# Name: URXUUR, dtype: int64
# 2    7149
# 1    2664
# Name: URDUURLC, dtype: int64
# 2    8552
# 1    1261
# Name: URXPREG, dtype: int64
# 2    7151
# 1    2662
# Name: URXUAS, dtype: int64
# 1    5316
# 2    4497
# Name: LBDB12, dtype: int64
# 1    5316
# 2    4497
# Name: LBDB12SI, dtype: int64

# %%
#Isolates the three columns we will be working with from the medicationsDf
newMed = medicationsDf[["SEQN", "Generic_Drug_Name", "ICD_10_CM_Code_1_Description"]]

#Renames the third column for readability
newMed = newMed.rename(columns={"ICD_10_CM_Code_1_Description": "Condition"})

#Replaces null perscriptions with a string value of "NONE"
newMed["Generic_Drug_Name"] = newMed["Generic_Drug_Name"].fillna("NONE")

#Corrects false data
newMed["Generic_Drug_Name"] = newMed["Generic_Drug_Name"].replace("99999", "NONE", regex=True)
newMed["Generic_Drug_Name"] = newMed["Generic_Drug_Name"].replace("55555", "NONE", regex=True)
newMed["Generic_Drug_Name"] = newMed["Generic_Drug_Name"].replace("77777", "NONE", regex=True)

#Cleans up condition names
newMed["Condition"] = newMed["Condition"].replace("Hypothyroidism, unspecified", "Hypothyroidism", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Major depressive disorder, single episode, unspecified", "Major depressive disorder", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Anxiety disorder, unspecified", "Anxiety disorder", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Sleep disorder, unspecified", "Sleep disorder", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Allergic rhinitis, unspecified", "Allergic rhinitis", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Dorsalgia, unspecified", "Dorsalgia", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Chronic obstructive pulmonary disease, unspecified", "Chronic obstructive pulmonary disease", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Neuralgia and neuritis, unspecified", "Neuralgia and neuritis", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Edema, unspecified", "Edema", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Heart failure, unspecified", "Heart failure", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Cardiac arrhythmia, unspecified", "Cardiac arrhythmia", regex=True)
newMed["Condition"] = newMed["Condition"].replace("Allergy, unspecified", "Allergy", regex=True)

# %%
#Creates a dataframe containing the top 15 used labs

toplabsDf = newLab[["SEQN","LBXRDW","LBXRBCSI","LBXHGB","LBXHCT","LBXMCVSI","LBXMCHSI","LBXPLTSI","LBXMPSI","LBXWBCSI","LBDBANO","LBDEONO","LBDMONO","LBDLYMNO","LBXBAPCT","LBXEOPCT","LBXNEPCT","LBXMOPCT","LBXLYPCT","LBDNENO","LBXHA","LBXHBS"]]

# %%
#Renames columns in toplabsDf for readability

toplabsDf = toplabsDf.rename(columns=\
                             {"LBXRDW":"Red cell distribution width (%)",
                             "LBXRBCSI":"Red blood cell count (million cells/uL)",
                             "LBXHGB":"Hemoglobin (g/dL)","LBXHCT":"Hematocrit (%)","LBXMCVSI":"Mean cell volume (fL)",
"LBXMCHSI":"Mean cell hemoglobin (pg)",
"LBXPLTSI":"Platelet count (1000 cells/uL)",
"LBXMPSI":"Mean platelet volume (fL)",
"LBXWBCSI":"White blood cell count (1000 cells/uL)",
"LBDBANO":"Basophils number (1000 cells/uL)",
"LBDEONO":"Eosinophils number (1000 cells/uL)",
"LBDMONO":"Monocyte number (1000 cells/uL)",
"LBDLYMNO":"Lymphocyte number (1000 cells/uL)",
"LBXBAPCT":"Basophils percent (%)",
"LBXEOPCT":"Eosinophils percent (%)",
"LBXNEPCT":"Segmented neutrophils percent (%)",
"LBXMOPCT":"Monocyte percent (%)",
"LBXLYPCT":"Lymphocyte percent (%)",
"LBDNENO":"Segmented neutrophils num (1000 cell/uL)",
"LBXHA":"Hepatitis A antibody",
"LBXHBS":"Hepatitis B Surface Antibody"
                             })

# %%
#Replaces values of 0 with values of 2 for future division

columnList = list(toplabsDf.columns.values)
columnList.pop(columnList.index('SEQN'))

for col in columnList:
   toplabsDf[col] = toplabsDf[col].replace(0, 2, regex=True)

# %%
#Renames the columns in demographicDf

demographicDf = demographicDf.rename(columns=\
                                    {
"SDDSRVYR":"Data release cycle",
"RIDSTATR":"Interview and examination status of the participant.",
"RIAGENDR":"Gender of the participant.",
"RIDAGEYR":"Age in years of the participant at the time of screening. Individuals 80 and over are topcoded at 80 years of age.",
"RIDAGEMN":"Age in months of the participant at the time of screening. Reported for persons aged 24 months or younger at the time of exam (or screening if not examined).",
"RIDRETH1":"Recode of reported race and Hispanic origin information",
"RIDRETH3":"Recode of reported race and Hispanic origin information, with Non-Hispanic Asian Category",
"RIDEXMON":"Six month time period when the examination was performed - two categories: November 1 through April 30, May 1 through October 31.",
"RIDEXAGM":"Age in months of the participant at the time of examination. Reported for persons aged 19 years or younger at the time of examination.",
"DMQMILIZ":"{Have you/Has SP} ever served on active duty in the U.S. Armed Forces, military Reserves, or National Guard? (Active duty does not include training for the Reserves or National Guard, but does include activation, for service in the U.S. or in a foreign country, in support of military or humanitarian operations.)",
"DMQADFC":"Did {you/SP} ever serve in a foreign country during a time of armed conflict or on a humanitarian or peace-keeping mission? (This would include National Guard or reserve or active duty monitoring or conducting peace keeping operations in Bosnia and Kosovo, in the Sinai between Egypt and Israel, or in response to the 2004 tsunami or Haiti in 2010.)",
"DMDBORN4":"In what country {were you/was SP} born?",
"DMDCITZN":"{Are you/Is SP} a citizen of the United States? [Information about citizenship is being collected by the U.S. Public Health Service to perform health related research. Providing this information is voluntary and is collected under the authority of the Public Health Service Act. There will be no effect on pending immigration or citizenship petitions.]",
"DMDYRSUS":"Length of time the participant has been in the US.",
"DMDEDUC3":"What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?",
"DMDEDUC2":"What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?",
"DMDMARTL":"Marital status",
"RIDEXPRG":"Pregnancy status for females between 20 and 44 years of age at the time of MEC exam.",
"SIALANG":"Language of the Sample Person Interview Instrument",
"SIAPROXY":"Was a Proxy respondent used in conducting the Sample Person (SP) interview?",
"SIAINTRP":"Was an interpreter used to conduct the Sample Person (SP) interview?",
"FIALANG":"Language of the Family Interview Instrument",
"FIAPROXY":"Was a Proxy respondent used in conducting the Family Interview?",
"FIAINTRP":"Was an interpreter used to conduct the Family interview?",
"MIALANG":"Language of the MEC CAPI Interview Instrument",
"MIAPROXY":"Was a Proxy respondent used in conducting the MEC CAPI Interview?",
"MIAINTRP":"Was an interpreter used to conduct the MEC CAPI interview?",
"AIALANGA":"Language of the MEC ACASI Interview Instrument",
"DMDHHSIZ":"Total number of people in the Household",
"DMDFMSIZ":"Total number of people in the Family",
"DMDHHSZA":"Number of children aged 5 years or younger in the household",
"DMDHHSZB":"Number of children aged 6-17 years old in the household",
"DMDHHSZE":"Number of adults aged 60 years or older in the household",
"DMDHRGND":"HH reference person's gender",
"DMDHRAGE":"HH reference person's age in years",
"DMDHRBR4":"HH reference person's country of birth",
"DMDHREDU":"HH reference person's education level",
"DMDHRMAR":"HH reference person's marital status",
"DMDHSEDU":"HH reference person's spouse's education level",
"WTINT2YR":"Full sample 2 year interview weight.",
"WTMEC2YR":"Full sample 2 year MEC exam weight.",
"SDMVPSU":"Masked variance unit pseudo-PSU variable for variance estimation",
"SDMVSTRA":"Masked variance unit pseudo-stratum variable for variance estimation",
"INDHHIN2":"Total household income (reported as a range value in dollars)",
"INDFMIN2":"Total family income (reported as a range value in dollars)",
"INDFMPIR":"A ratio of family income to poverty guidelines."})

# %%
# Create a new dataframe with selected columns from the demographicDF 
demographicDf1 = demographicDf[["SEQN","Gender of the participant.", "Age in years of the participant at the time of screening. Individuals 80 and over are topcoded at 80 years of age." ,"Marital status" ,"Pregnancy status for females between 20 and 44 years of age at the time of MEC exam." , "Did {you/SP} ever serve in a foreign country during a time of armed conflict or on a humanitarian or peace-keeping mission? (This would include National Guard or reserve or active duty monitoring or conducting peace keeping operations in Bosnia and Kosovo, in the Sinai between Egypt and Israel, or in response to the 2004 tsunami or Haiti in 2010.)" , "What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?" , "What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?"]]

# %%
#Renames the columns in demographicDf1
demographicDf1 = demographicDf1.rename(columns=\
                                    {"Gender of the participant.": "Gender",\
                                      "Age in years of the participant at the time of screening. Individuals 80 and over are topcoded at 80 years of age.": "Age",\
                                      "Pregnancy status for females between 20 and 44 years of age at the time of MEC exam.": "Pregnancy_Status", \
                                      "Did {you/SP} ever serve in a foreign country during a time of armed conflict or on a humanitarian or peace-keeping mission? (This would include National Guard or reserve or active duty monitoring or conducting peace keeping operations in Bosnia and Kosovo, in the Sinai between Egypt and Israel, or in response to the 2004 tsunami or Haiti in 2010.)": "Served",\
                                      "What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?": "Education1",\
                                      "What is the highest grade or level of school {you have/SP has} completed or the highest degree {you have/s/he has} received?": "Education2"
                                     
                                    })

# %%
#Drops columns we don't need, such as education and military status

demographicDf1 = demographicDf1[["SEQN", "Gender", "Age", "Marital status", "Pregnancy_Status"]]

# %%
demographicDf1["Pregnancy_Status"].unique()
# Out:
# array([nan,  2.,  1.,  3.])
